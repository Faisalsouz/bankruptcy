# %%
import numpy as np
import pandas as pd
import pickle

# %%
# read data
data = pd.read_csv('data.csv', dtype=object)

data.head()
# Out:
#   Instrument  Total Debt Accounts Payable (CF)  \
# 0     910655   1866000.0             -235000.0
# 1    1116521  10000000.0           -47000000.0
# 2     895651    377000.0                   NaN
# 3    1398702         NaN                   NaN
# 4    1434621         NaN                   NaN
#
#                       NAICS Industry Group Name Inventories (CF)  \
# 0  Motor Vehicle Body and Trailer Manufacturing       -9289000.0
# 1        Communications Equipment Manufacturing       81000000.0
# 2         Offices of Other Health Practitioners         289000.0
# 3                         Tobacco Manufacturing              NaN
# 4           Nondepository Credit Intermediation              NaN
#
#   Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 0                 1.0                              49741000.0
# 1                 1.0                                     NaN
# 2                 1.0                             -18251000.0
# 3                 0.0                                     NaN
# 4                 0.0                                     NaN
#
#   Net Debt Incl. Pref.Stock & Min.Interest Total Current Assets  \
# 0                               -8580000.0           82689000.0
# 1                             -184000000.0         3043000000.0
# 2                               -1483000.0            9479000.0
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
#
#   Total Liabilities  ... Tangible Book Value Per Share     Net Sales  \
# 0        23250000.0  ...                       8.43993   360326000.0
# 1      2422000000.0  ...                       5.59129  8268000000.0
# 2        13186000.0  ...                        0.4067    54971000.0
# 3               NaN  ...                           NaN           NaN
# 4               NaN  ...                           NaN           NaN
#
#   Operating Income Instrument Is Active Flag Tangible Book Value - Utility  \
# 0       40075000.0                       0.0                    87124000.0
# 1      369000000.0                       0.0                  1556000000.0
# 2       -1056000.0                       0.0                     3622000.0
# 3              NaN                       1.0                           NaN
# 4              NaN                       1.0                           NaN
#
#   Total Assets, Reported Depreciation And Amortization  \
# 0            117739000.0                      413000.0
# 1           4239000000.0                           NaN
# 2             32145000.0                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   Total Current Liabilities  Year Bankrupt
# 0                19209000.0  2000        1
# 1              1597000000.0  2000        1
# 2                 6303000.0  2000        1
# 3                       NaN  2000        1
# 4                       NaN  2000        1
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Healthy Companies Data

# %%
# extract the healthy dataframe
healthy_raw = data[data['Bankrupt'] == '0']

healthy_raw.head()
# Out:
#       Instrument    Total Debt Accounts Payable (CF)  \
# 24200       1750   181359000.0            24659000.0
# 24201      61478    49900000.0            45000000.0
# 24202     319126     6402000.0             -300000.0
# 24203     730469   483008000.0                   NaN
# 24204       6201  4402000000.0                   NaN
#
#                                NAICS Industry Group Name Inventories (CF)  \
# 24200          Aerospace Product and Parts Manufacturing      -46212000.0
# 24201             Communications Equipment Manufacturing      -66700000.0
# 24202  Navigational, Measuring, Electromedical, and C...         665000.0
# 24203                   Other Investment Pools and Funds        1255000.0
# 24204                       Scheduled Air Transportation      -36000000.0
#
#       Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 24200                 0.0                             184529000.0
# 24201                 1.0                             899200000.0
# 24202                 0.0                              -6361000.0
# 24203                 1.0                              56649000.0
# 24204                 0.0                            4733000000.0
#
#       Net Debt Incl. Pref.Stock & Min.Interest Total Current Assets  \
# 24200                              173109000.0          508186000.0
# 24201                             -484600000.0         1376600000.0
# 24202                                6153000.0            9758000.0
# 24203                              468594000.0          335484000.0
# 24204                             2867000000.0         3969000000.0
#
#       Total Liabilities  ... Tangible Book Value Per Share      Net Sales  \
# 24200       400595000.0  ...                      10.44308   1050608000.0
# 24201       462500000.0  ...                      14.01205   2151800000.0
# 24202         8778000.0  ...                     129.66559     29370000.0
# 24203       641657000.0  ...                      -1.79517    600282000.0
# 24204     14757000000.0  ...                      33.90123  17516000000.0
#
#       Operating Income Instrument Is Active Flag  \
# 24200       77381000.0                       1.0
# 24201      135000000.0                       0.0
# 24202       -1682000.0                       1.0
# 24203       62651000.0                       0.0
# 24204     1988000000.0                       1.0
#
#       Tangible Book Value - Utility Total Assets, Reported  \
# 24200                   285942000.0            726630000.0
# 24201                  1358300000.0           2057800000.0
# 24202                     2404000.0             13986000.0
# 24203                   -48430000.0            908936000.0
# 24204                  5470000000.0          21455000000.0
#
#       Depreciation And Amortization Total Current Liabilities  Year Bankrupt
# 24200                           NaN               173586000.0  2000        0
# 24201                    22200000.0               448500000.0  2000        0
# 24202                           NaN                 2804000.0  2000        0
# 24203                           NaN               170437000.0  2000        0
# 24204                  1040000000.0              5302000000.0  2000        0
#
# [5 rows x 29 columns]

# %%
for col in healthy_raw.columns:
    print(col)

print()
print(len(healthy_raw.columns))
# Out:
# Instrument
# Total Debt
# Accounts Payable (CF)
# NAICS Industry Group Name
# Inventories (CF)
# Delisted Quote Flag
# Retained Earnings (Accumulated Deficit)
# Net Debt Incl. Pref.Stock & Min.Interest
# Total Current Assets
# Total Liabilities
# Company Common Name
# CIK Number
# Total Equity
# Tangible Book Value - Banks
# Tangible Book Value - Insurance
# Net Income/Starting Line, Cumulative
# Tangible Book Value - Reported
# Cash and Short Term Investments
# Market Value for Company
# Tangible Book Value Per Share
# Net Sales
# Operating Income
# Instrument Is Active Flag
# Tangible Book Value - Utility
# Total Assets, Reported
# Depreciation And Amortization
# Total Current Liabilities
# Year
# Bankrupt
#
# 29

# %%
# drop non-quantitative columns
healthy = healthy_raw.drop(columns=['NAICS Industry Group Name', 'Delisted Quote Flag', 'Company Common Name',
                                    'CIK Number', 'Instrument Is Active Flag', 'Bankrupt'])

healthy.head()
# Out:
#       Instrument    Total Debt Accounts Payable (CF) Inventories (CF)  \
# 24200       1750   181359000.0            24659000.0      -46212000.0
# 24201      61478    49900000.0            45000000.0      -66700000.0
# 24202     319126     6402000.0             -300000.0         665000.0
# 24203     730469   483008000.0                   NaN        1255000.0
# 24204       6201  4402000000.0                   NaN      -36000000.0
#
#       Retained Earnings (Accumulated Deficit)  \
# 24200                             184529000.0
# 24201                             899200000.0
# 24202                              -6361000.0
# 24203                              56649000.0
# 24204                            4733000000.0
#
#       Net Debt Incl. Pref.Stock & Min.Interest Total Current Assets  \
# 24200                              173109000.0          508186000.0
# 24201                             -484600000.0         1376600000.0
# 24202                                6153000.0            9758000.0
# 24203                              468594000.0          335484000.0
# 24204                             2867000000.0         3969000000.0
#
#       Total Liabilities  Total Equity Tangible Book Value - Banks  ...  \
# 24200       400595000.0   326035000.0                 285942000.0  ...
# 24201       462500000.0  1595300000.0                1358300000.0  ...
# 24202         8778000.0     5208000.0                   2404000.0  ...
# 24203       641657000.0   267279000.0                 -48430000.0  ...
# 24204     14757000000.0  6698000000.0                5470000000.0  ...
#
#       Cash and Short Term Investments Market Value for Company  \
# 24200                       8250000.0              481230000.0
# 24201                     534500000.0            10975190000.0
# 24202                        249000.0                3480000.0
# 24203                      14414000.0                      NaN
# 24204                    1535000000.0                      NaN
#
#       Tangible Book Value Per Share      Net Sales Operating Income  \
# 24200                      10.44308   1050608000.0       77381000.0
# 24201                      14.01205   2151800000.0      135000000.0
# 24202                     129.66559     29370000.0       -1682000.0
# 24203                      -1.79517    600282000.0       62651000.0
# 24204                      33.90123  17516000000.0     1988000000.0
#
#       Tangible Book Value - Utility Total Assets, Reported  \
# 24200                   285942000.0            726630000.0
# 24201                  1358300000.0           2057800000.0
# 24202                     2404000.0             13986000.0
# 24203                   -48430000.0            908936000.0
# 24204                  5470000000.0          21455000000.0
#
#       Depreciation And Amortization Total Current Liabilities  Year
# 24200                           NaN               173586000.0  2000
# 24201                    22200000.0               448500000.0  2000
# 24202                           NaN                 2804000.0  2000
# 24203                           NaN               170437000.0  2000
# 24204                  1040000000.0              5302000000.0  2000
#
# [5 rows x 23 columns]

# %%
# replace all NAN values with 0 and non-NANs with 1
healthy = healthy.notnull().astype('int')

# except for the instruments and the year
healthy['Instrument'] = healthy_raw['Instrument']
healthy['Year'] = healthy_raw['Year']


healthy.head()
# Out:
#       Instrument  Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# 24200       1750           1                      1                 1
# 24201      61478           1                      1                 1
# 24202     319126           1                      1                 1
# 24203     730469           1                      0                 1
# 24204       6201           1                      0                 1
#
#        Retained Earnings (Accumulated Deficit)  \
# 24200                                        1
# 24201                                        1
# 24202                                        1
# 24203                                        1
# 24204                                        1
#
#        Net Debt Incl. Pref.Stock & Min.Interest  Total Current Assets  \
# 24200                                         1                     1
# 24201                                         1                     1
# 24202                                         1                     1
# 24203                                         1                     1
# 24204                                         1                     1
#
#        Total Liabilities  Total Equity  Tangible Book Value - Banks  ...  \
# 24200                  1             1                            1  ...
# 24201                  1             1                            1  ...
# 24202                  1             1                            1  ...
# 24203                  1             1                            1  ...
# 24204                  1             1                            1  ...
#
#        Cash and Short Term Investments  Market Value for Company  \
# 24200                                1                         1
# 24201                                1                         1
# 24202                                1                         1
# 24203                                1                         0
# 24204                                1                         0
#
#        Tangible Book Value Per Share  Net Sales  Operating Income  \
# 24200                              1          1                 1
# 24201                              1          1                 1
# 24202                              1          1                 1
# 24203                              1          1                 1
# 24204                              1          1                 1
#
#        Tangible Book Value - Utility  Total Assets, Reported  \
# 24200                              1                       1
# 24201                              1                       1
# 24202                              1                       1
# 24203                              1                       1
# 24204                              1                       1
#
#        Depreciation And Amortization  Total Current Liabilities  Year
# 24200                              0                          1  2000
# 24201                              1                          1  2000
# 24202                              0                          1  2000
# 24203                              0                          1  2000
# 24204                              1                          1  2000
#
# [5 rows x 23 columns]

# %%
for col in healthy.columns:
    print(col)

print()
print(len(healthy.columns))
# Out:
# Instrument
# Total Debt
# Accounts Payable (CF)
# Inventories (CF)
# Retained Earnings (Accumulated Deficit)
# Net Debt Incl. Pref.Stock & Min.Interest
# Total Current Assets
# Total Liabilities
# Total Equity
# Tangible Book Value - Banks
# Tangible Book Value - Insurance
# Net Income/Starting Line, Cumulative
# Tangible Book Value - Reported
# Cash and Short Term Investments
# Market Value for Company
# Tangible Book Value Per Share
# Net Sales
# Operating Income
# Tangible Book Value - Utility
# Total Assets, Reported
# Depreciation And Amortization
# Total Current Liabilities
# Year
#
# 23

# %%
healthy = healthy.groupby(['Instrument', 'Year']).sum().reset_index()
healthy['noNANs'] = healthy.sum(axis=1)
healthy = healthy[['Instrument', 'Year', 'noNANs']]

healthy.head()
# Out:
#   Instrument  Year  noNANs
# 0    1000045  2000      17
# 1    1000045  2001      17
# 2    1000045  2002      18
# 3    1000045  2003      18
# 4    1000045  2004      17

# %%
healthy.noNANs.max()
# Out:
# 21

# %% [markdown]
# ## Bankrupt Companies Dates Data

# %%
# read the bankruptcy dates
bankrupt = pd.read_csv('bankruptcy_dates.csv', dtype={'CIK': 'str'}, index_col=0)
# sort by date
bankrupt.sort_values(by=['Date'], inplace=True)

bankrupt
# Out:
#           CIK                             Company  Date
# 8        6125            Keystone Camera Products  1992
# 29     797422               Hi-Def Enterprise Inc  1993
# 23     822373                         Namsco Corp  1994
# 12      87817        Scientific Radio Systems Inc  1995
# 645   1129981            OGLEBAY NORTON CO /OHIO/  2004
# 88     225463                          HUFFY CORP  2004
# 519   1069201          CROSS MEDIA MARKETING CORP  2004
# 122    701345                US AIRWAYS GROUP INC  2004
# 598   1107080                  ENVIRO ENERGY CORP  2004
# 188    801550                             DVI INC  2004
# 626   1121131    REDLINE PERFORMANCE PRODUCTS INC  2004
# 52      66895      MISSISSIPPI CHEMICAL CORP /MS/  2004
# 217    829499        INTERSTATE BAKERIES CORP/DE/  2004
# 87     225211                         BICO INC/PA  2004
# 186    800181                 MED DIVERSIFIED INC  2004
# 560   1091953       CHOICE ONE COMMUNICATIONS INC  2004
# 35      38792         FRANKS NURSERY & CRAFTS INC  2004
# 77     100979                 ARIS INDUSTRIES INC  2004
# 352    930735          CROWN PACIFIC PARTNERS L P  2004
# 85     203200                         METATEC INC  2004
# 343    924174               CORAM HEALTHCARE CORP  2004
# 701   1170161                   IDEAL ACCENTS INC  2004
# 165    773326                       FORELAND CORP  2004
# 648   1131806              COMMERCE ONE INC / DE/  2004
# 271    878720         CHILDREN S BOOKS & TOYS INC  2004
# 524   1071645              WORLD ACCESS INC /NEW/  2004
# 54      73088                   NORTHWESTERN CORP  2004
# 511   1064063                      MIIX GROUP INC  2004
# 276    879206                            USN CORP  2004
# 185    797542             ZAXIS INTERNATIONAL INC  2004
# ...       ...                                 ...   ...
# 56      73887                   Bristow Group Inc  2019
# 59      76321             PARKER DRILLING CO /DE/  2019
# 522   1071411                Fusion Connect, Inc.  2019
# 856   1347613       SYNERGY PHARMACEUTICALS, INC.  2019
# 997   1437106          Ascent Capital Group, Inc.  2019
# 1073  1720201             iPic Entertainment Inc.  2019
# 266    872248               PETROQUEST ENERGY INC  2019
# 443   1024126  PERNIX THERAPEUTICS HOLDINGS, INC.  2019
# 1036  1528837                 Sanchez Energy Corp  2019
# 1055  1573166                  Jones Energy, Inc.  2019
# 1070  1656328     Sienna Biopharmaceuticals, Inc.  2019
# 1048  1555177           Emerge Energy Services LP  2019
# 1072  1690769       Alta Mesa Resources, Inc. /DE  2019
# 1053  1568079                    PetroShare Corp.  2019
# 1062  1586105                         Egalet Corp  2019
# 1061  1584952                       EP Energy LLC  2019
# 1056  1575360                 FTD Companies, Inc.  2019
# 476   1045425                RAIT Financial Trust  2019
# 1066  1603923       Weatherford International plc  2019
# 1033  1518403              Alta Mesa Holdings, LP  2019
# 789   1301501                      Achaogen, Inc.  2019
# 755   1282266            WINDSTREAM SERVICES, LLC  2019
# 745   1265107       MONITRONICS INTERNATIONAL INC  2019
# 306    896985          Destination Maternity Corp  2019
# 726   1208261          IMMUNE PHARMACEUTICALS INC  2019
# 216    827809          NOVELION THERAPEUTICS INC.  2019
# 396   1004980                           PG&E Corp  2019
# 411   1013238                        ARADIGM CORP  2019
# 607   1109196  MABVAX THERAPEUTICS HOLDINGS, INC.  2019
# 1074  1735828                Legacy Reserves Inc.  2019
#
# [1175 rows x 3 columns]

# %%
# keep only bankrupt companies that went bankrupt after 2006
bankrupt = bankrupt[bankrupt.Date > 2005]
dates = bankrupt.groupby(['Date']).count()

dates
# Out:
#       CIK  Company
# Date
# 2006   59       59
# 2007   85       85
# 2008   94       94
# 2009  177      177
# 2010   93       93
# 2011   66       66
# 2012   72       72
# 2013   64       64
# 2014   56       56
# 2015   52       52
# 2016   96       96
# 2017   55       55
# 2018   40       40
# 2019   46       46

# %% [markdown]
# # The Situation
#
# So here we have 14 years, in each a specific number of bankrupt comapnies. Now we want to extract 5 healthy companies for each bankrupt one. Plus, this data should be collected from a period of year-7 to year-5.
#
# So for example, we need data for 93 * 5 healthy companies in years 2004 to 2008 (inclusive), for 93 companies that went bankrupt in 2010.
#
#
# On the other hand, we have a dataframe of healthy companies CIK code for each year (2000-2019) and a column showing the number of non-NAN values for each row. A no-NANs equal to 21 indicate that the company for that year has full data.
# Now our goal is to pick those 5 company for each bankrupt companies from ones with the highest no-NANs values.
#
#
#
# ## The Strategy
#
# For each time period, we calculate the sum of no-NANs for that period and pick the n maximums; n being the number of companiets that went bankrupt in year+1. So we have to do it 14 times (2007-2019).

# %%
healthy.head()
# Out:
#   Instrument  Year  noNANs
# 0    1000045  2000      17
# 1    1000045  2001      17
# 2    1000045  2002      18
# 3    1000045  2003      18
# 4    1000045  2004      17

# %%
healthy['Year'] = healthy['Year'].apply(lambda x: int(x))

# %%
# write a function for the task

def extract_healthy(df, year, n):
    '''
    The function takes the year in which n companies went bankrupt,
    and from the healthy dataframe, returns a CIK lists of 5 * n
    healthy companies which 6 years to 2 years before that year has
    the fullest dataset.
    '''
    
    # first remove all the extra rows for years not in the period
    df_temp = df[(df.Year < year-1) & (df.Year > year-7)]
    # group the dataframe by instrument, sum over the no-NANs
    df_temp = df_temp.groupby(['Instrument']).sum()
    # drop the now useless year column
    df_temp.drop(columns=['Year'], inplace=True)
    # descending-sort the companies based on noNANs magnitude
    df_temp.sort_values(by=['noNANs'], ascending=False, inplace=True)
    # cut the first n * 5 ones
    df_temp = df_temp[:5*n]
    # make a list of their CIK cides
    CIK_list = df_temp.index.to_list()
    # drop the healthy companies already picked from the df
     
    
    return CIK_list

# %%
# keep the original df safe, just in case
healthy_copy = healthy.copy()

# create a dic storing the CIK lists for different years
CIK_year = {}

# loop over all available years in our dataset
for year in range(2019, 2005, -1):
    # take the number of companies went bankrupt in that year
    n = int(dates[dates.index == year]['Company'])
    # take the CIK list
    CIK_list = extract_healthy(healthy_copy, year, n)
    # add the list to the dictionary
    CIK_year[year] = CIK_list
    

print(CIK_year)
# Out:
# {2019: ['106640', '1406574', '1031028', '1278027', '944400', '110430', '920532', '854800', '1323653', '880059', '723928', '1080029', '1476170', '724606', '1406243', '1406635', '72316', '1406666', '1358071', '929994', '1097864', '726845', '726958', '1477246', '1424768', '815093', '1033905', '13573', '915862', '799097', '829224', '722723', '885012', '1030206', '1323854', '866970', '1057807', '1029738', '830052', '1080667', '944809', '1123494', '1275283', '854398', '1030058', '1275712', '880460', '944765', '880266', '910111', '15847', '1123316', '721371', '880446', '1474735', '1104252', '1582244', '800286', '1404804', '722392', '1581804', '1358700', '1057083', '1572621', '815097', '941604', '1286973', '1287213', '740726', '941685', '1036960', '825322', '1409565', '915778', '742278', '1288741', '1056358', '743316', '743988', '1037646', '1121142', '1037649', '797721', '745655', '878079', '1056285', '1038143', '1038144', '1550935', '1481055', '1117795', '1423221', '1056087', '1038280', '1479426', '1036292', '825542', '1286597', '1056923', '879303', '922913', '730255', '1034957', '730263', '1321646', '943452', '1567529', '1078075', '1565228', '1120370', '1321544', '1120295', '1284823', '943034', '1078037', '943003', '7332', '736822', '103595', '82628', '1105542', '1119951', '1036044', '738076', '73887', '719209', '1081022', '1029199', '1325159', '946840', '1094084', '832370', '68145', '1070235', '884144', '1023734', '1325281', '852937', '883981', '1362120', '6955', '69671', '1024022', '1324948', '1263011', '1024126', '909326', '1607245', '1263074', '700998', '1361916', '859365', '909494', '701719', '1471458', '1094324', '1024725', '832407', '6769', '909037', '1023362', '1613780', '1022368', '1469395', '1059677', '803003', '1128928', '884887', '866706', '916365', '1022652', '1022671', '1325955', '1128252', '802356', '852766', '1362614', '852772', '866729', '1397966', '1260221', '1023128', '832488', '1023131', '1023139', '1362516', '866734', '920148', '703351', '1604858', '1029145', '1094739', '929008', '714256', '1324105', '1081751', '13610', '71557', '882235', '882154', '1402606', '913142', '716643', '945699', '1323974', '1271940', '800937', '1058090', '945641', '1272597', '717954', '718096', '1272830', '1103982', '1070412', '94538', '1124024', '1425905', '853971', '1403431', '712843', '1268471', '712034', '1125259', '883943', '1314592', '923601', '883907', '800901', '1058811'], 2018: ['907242', '930803', '800286', '1295810', '1295947', '1448397', '1296205', '1057083', '1056923', '49826', '1056358', '1056285', '929994', '1056087', '800901', '1298341', '800937', '48039', '47217', '50292', '1449877', '929008', '50863', '1059677', '1453593', '1290900', '928054', '5117', '1292087', '1058811', '1452217', '1057807', '1451951', '1292900', '1058090', '1058057', '928659', '875296', '1057997', '46765', '1602397', '875657', '46129', '1051114', '869986', '1050952', '869487', '1439124', '1306830', '80420', '42136', '804212', '1050140', '804753', '4127', '1437598', '1050007', '40987', '40888', '1309167', '870228', '4281', '1051488', '1441849', '1443242', '1443062', '45919', '873044', '1442505', '1052595', '1301787', '802356', '1439636', '1302362', '1302707', '1051846', '803003', '870753', '1303849', '1051512', '1289877', '1060009', '880460', '1278027', '1469395', '793733', '61986', '1069353', '1069336', '6176', '1275283', '923601', '879796', '1468642', '1067701', '1468091', '1067294', '1066961', '1066923', '60667', '879303', '15847', '1584549', '880059', '107140', '791519', '791531', '1071941', '1582244', '1471458', '63814', '922486', '1071337', '1070235', '880266', '1271940', '1272597', '63271', '1272830', '1070412', '922913', '106640', '795212', '1289814', '795551', '1062449', '877212', '1286973', '1287213', '1456453', '1456189', '927003', '1288741', '927066', '54441', '799097', '876160', '5337', '1289460', '1060426', '875762', '1060390', '877365', '56047', '1284823', '925660', '1466815', '1065860', '796124', '1065696', '1065677', '58492', '1463 ...

# %%
# write the dictionary
with open('CIK_year.txt', 'wb') as f:
    pickle.dump(CIK_year, f)

# %% [markdown]
# ## Second Strategy
#
# This time I will create a dataframe, with the rows being healthy companies, and the columns being the 5-year periods, so to calculate the fullness of each healthy company for each period for an optimal selection.

# %%
healthy.head()
# Out:
#   Instrument  Year  noNANs
# 0    1000045  2000      17
# 1    1000045  2001      17
# 2    1000045  2002      18
# 3    1000045  2003      18
# 4    1000045  2004      17

# %%
def score_cal(df, year):
        '''
        The function takes the healthy df and a year, and calculate the
        healthy companies' scores (#non-NAN-values) for 6 years to 2
        years before that year, and returns it in a dataseries.
        '''
        
        # first remove all the extra rows for years not in the period
        df_temp = df[(df.Year < year-1) & (df.Year > year-7)]
        # group the dataframe by instrument, sum over the no-NANs
        df_temp = df_temp.groupby(['Instrument']).sum()

        return df_temp.noNANs


    
def extract_healthy_2(df):
    '''
    This function takes a healthy dataframe and and returns a
    dataframe stating each company's score (non-NAN values) for
    a period.
    '''

    # create a new dataframe to store each company score per period
    df_out = df.groupby(['Instrument']).sum()
    
    for year in range(2019, 2005, -1):
        # set the column title
        title = str(year) + ':(' + str(year-6) + '-' + str(year-2) + ')'
        df_out[title] = np.around((score_cal(df, year) / 105 * 100), decimals=2)
        
    df_out.drop(columns=['Year', 'noNANs'], inplace=True)
        
    return df_out

# %%
dfout = extract_healthy_2(healthy)

dfout
# Out:
#             2019:(2013-2017)  2018:(2012-2016)  2017:(2011-2015)  \
# Instrument
# 1000045                80.95             80.95             80.00
# 1000157                90.48             90.48             90.48
# 1000177                99.05             99.05             99.05
# 1000180               100.00            100.00            100.00
# 1000184                90.48             90.48             90.48
# 1000209                76.19             76.19             76.19
# 1000227                90.48             90.48             90.48
# 1000228                90.48             90.48             90.48
# 1000229               100.00            100.00            100.00
# 1000230                95.24             95.24             95.24
# 1000232                57.14             57.14             57.14
# 1000234                57.14             57.14             57.14
# 1000275                57.14             57.14             57.14
# 1000278                90.48             90.48             90.48
# 1000297                85.71             85.71             85.71
# 1000298                75.24             74.29             73.33
# 1000300                80.95             80.95             80.95
# 1000368                95.24             95.24             95.24
# 1000623                95.24             95.24             95.24
# 1000683                90.48             90.48             90.48
# 1000694                85.71             85.71             85.71
# 1000695                95.24             95.24             95.24
# 1000697               100.00            100.00            100.00
# 1000736                95.24             95.24             95.24
# 1000753                95.24             95.24             95.24
# 1000779                85.71             85.71             85.71
# 1001082               100.00            100.00            100.00
# 1001085                80.95             80.95             80.95
# 1001111                95.24             95.24             95.24
# 1001113                80.95             80.95             80.95
# ...                      ...               ...               ...
# 97517                  76.19             76.19             76.19
# 97745                  95.24             95.24             95.24
# 97854                  95.24             95.24             95.24
# 9801                   90.48             90.48             90.48
# 98222                 100.00            100.00            100.00
# 98246                  90.48             90.48             90.48
# 98338                  85.71             85.71             85.71
# 98362                  95.24             95.24             94.29
# 98537                  90.48             90.48             90.48
# 98544                  85.71             85.71             85.71
# 98573                  95.24             95.24             95.24
# 98618                  88.57             90.48             92.38
# 98677                  90.48             90.48             90.48
# 98720                   0.00              0.00              0.00
# 98752                  95.24             95.24             95.24
# 98827                   4.76              4.76              4.76
# 98840                   0.00              0.00              0.00
# 9892                   90.48             90.48             90.48
# 99047                  85.71             85.71             85.71
# 99070                  91.43             91.43             92.38
# 99106                  91.43             90.48             90.48
# 99197                   9.52              9.52              9.52
# 99249                  84.76             85.71             86.67
# 99250                  95.24             95.24             95.24
# 99302                  95.24             95.24             95.24
# 99313                  90.48             90.48             90.48
# 99359                  95.24             95.24             95.24
# 99614                  71.43             71.43             71.43
# 99780                  85.71             85.71             85.71
# 9984                   95.24             95.24             95.24
#
#             2016:(2010-2014)  2015:(2009-2013)  2014:(2008-2012)  \
# Instrument
# 1000045                79.05             79.05             79.05
# 1000157                90.48             90.48             90.48
# 1000177                98.10             97.14             96.19
# 1000180               100.00            100.00            100.00
# 1000184                89.52             88.57             87.62
# 1000209                76.19             76.19             77.14
# 1000227                90.48             90.48             90.48
# 1000228                90.48             90.48             90.48
# 1000229               100.00            100.00            100.00
# 1000230                95.24             95.24             96.19
# 1000232                57.14             57.14             57.14
# 1000234                57.14             57.14             57.14
# 1000275                57.14             57.14             57.14
# 1000278                90.48             90.48             91.43
# 1000297                85.71             85.71             85.71
# 1000298                72.38             71.43             71.43
# 1000300                80.95             80.95             80.95
# 1000368                95.24             95.24             95.24
# 1000623                95.24             95.24             95.24
# 1000683                90.48             90.48             90.48
# 1000694                85.71             85.71             86.67
# 1000695                95.24             95.24             95.24
# 1000697               100.00            100.00            100.00
# 1000736                95.24             95.24             95.24
# 1000753                95.24             95.24             95.24
# 1000779                85.71             85.71             85.71
# 1001082               100.00            100.00            100.00
# 1001085                80.95             80.95             80.95
# 1001111                95.24             95.24             95.24
# 1001113                80.95             80.95             80.95
# ...                      ...               ...               ...
# 97517                  76.19             76.19             76.19
# 97745                  95.24             95.24             95.24
# 97854                  95.24             95.24             95.24
# 9801                   90.48             90.48             90.48
# 98222                 100.00            100.00             99.05
# 98246                  90.48             90.48             90.48
# 98338                  85.71             85.71             85.71
# 98362                  93.33             92.38             91.43
# 98537                  90.48             90.48             90.48
# 98544                  85.71             85.71             85.71
# 98573                  95.24             95.24             95.24
# 98618                  94.29             95.24             95.24
# 98677                  90.48             90.48             90.48
# 98720                   0.00              0.00              0.00
# 98752                  96.19             97.14             98.10
# 98827                   4.76              4.76              4.76
# 98840                   0.00              0.00              0.00
# 9892                   90.48             90.48             90.48
# 99047                  85.71             85.71             85.71
# 99070                  94.29             96.19             98.10
# 99106                  90.48             90.48             90.48
# 99197                   8.57              7.62              6.67
# 99249                  87.62             87.62             88.57
# 99250                  95.24             95.24             95.24
# 99302                  95.24             95.24             95.24
# 99313                  90.48             90.48             90.48
# 99359                  95.24             95.24             95.24
# 99614                  71.43             72.38             73.33
# 99780                  85.71             85.71             84.76
# 9984                   95.24             95.24             95.24
#
#             2013:(2007-2011)  2012:(2006-2010)  2011:(2005-2009)  \
# Instrument
# 1000045                79.05             80.00             80.95
# 1000157                90.48             90.48             90.48
# 1000177                95.24             95.24             95.24
# 1000180               100.00            100.00             99.05
# 1000184                86.67             85.71             85.71
# 1000209                78.10             79.05             80.00
# 1000227                90.48             90.48             90.48
# 1000228                90.48             90.48             90.48
# 1000229               100.00            100.00            100.00
# 1000230                96.19             96.19             96.19
# 1000232                57.14             57.14             57.14
# 1000234                57.14             57.14             57.14
# 1000275                57.14             57.14             57.14
# 1000278                92.38             93.33             94.29
# 1000297                85.71             85.71             85.71
# 1000298                72.38             73.33             74.29
# 1000300                80.95             80.95             80.95
# 1000368                94.29             92.38             77.14
# 1000623                95.24             95.24             95.24
# 1000683                90.48             90.48             90.48
# 1000694                87.62             88.57             89.52
# 1000695                95.24             95.24             95.24
# 1000697               100.00            100.00            100.00
# 1000736                95.24             95.24             95.24
# 1000753                95.24             95.24             95.24
# 1000779                85.71             85.71             85.71
# 1001082               100.00            100.00            100.00
# 1001085                80.95             80.95             80.00
# 1001111                95.24             95.24             95.24
# 1001113                80.95             80.95             80.95
# ...                      ...               ...               ...
# 97517                  76.19             76.19             76.19
# 97745                  95.24             95.24             96.19
# 97854                  95.24             95.24             95.24
# 9801                   90.48             90.48             90.48
# 98222                  99.05             98.10             97.14
# 98246                  90.48             90.48             90.48
# 98338                  85.71             85.71             85.71
# 98362                  90.48             90.48             90.48
# 98537                  90.48             90.48             90.48
# 98544                  85.71             85.71             85.71
# 98573                  95.24             95.24             95.24
# 98618                  95.24             94.29             93.33
# 98677                  90.48             90.48             91.43
# 98720                   0.00              0.00              0.00
# 98752                  99.05            100.00            100.00
# 98827                   4.76              4.76              4.76
# 98840                   0.00              0.00              0.00
# 9892                   90.48             90.48             90.48
# 99047                  85.71             85.71             85.71
# 99070                 100.00            100.00            100.00
# 99106                  90.48             90.48             90.48
# 99197                   5.71              4.76              4.76
# 99249                  87.62             86.67             85.71
# 99250                  95.24             95.24             95.24
# 99302                  95.24             95.24             95.24
# 99313                  90.48             90.48             90.48
# 99359                  95.24             95.24             95.24
# 99614                  74.29             75.24             76.19
# 99780                  83.81             82.86             81.90
# 9984                   95.24             95.24             95.24
#
#             2010:(2004-2008)  2009:(2003-2007)  2008:(2002-2006)  \
# Instrument
# 1000045                80.95             81.90             82.86
# 1000157                90.48             90.48             90.48
# 1000177                95.24             94.29             93.33
# 1000180                98.10             97.14             96.19
# 1000184                85.71             85.71             85.71
# 1000209                80.95             80.95             80.95
# 1000227                90.48             90.48             90.48
# 1000228                90.48             90.48             90.48
# 1000229               100.00            100.00            100.00
# 1000230                96.19             95.24             95.24
# 1000232                57.14             57.14             57.14
# 1000234                57.14             57.14             57.14
# 1000275                57.14             57.14             57.14
# 1000278                95.24             95.24             95.24
# 1000297                85.71             85.71             85.71
# 1000298                75.24             76.19             76.19
# 1000300                80.95             80.95             80.95
# 1000368                61.90             43.81             26.67
# 1000623                95.24             95.24             95.24
# 1000683                90.48             90.48             90.48
# 1000694                90.48             90.48             90.48
# 1000695                95.24             95.24             95.24
# 1000697               100.00            100.00            100.00
# 1000736                95.24             95.24             95.24
# 1000753                95.24             95.24             95.24
# 1000779                85.71             85.71             85.71
# 1001082               100.00            100.00            100.00
# 1001085                79.05             77.14             75.24
# 1001111                94.29             80.00             61.90
# 1001113                80.95             80.95             80.95
# ...                      ...               ...               ...
# 97517                  76.19             76.19             76.19
# 97745                  97.14             98.10             98.10
# 97854                  95.24             95.24             95.24
# 9801                   90.48             90.48             90.48
# 98222                  96.19             96.19             95.24
# 98246                  91.43             92.38             93.33
# 98338                  85.71             85.71             85.71
# 98362                  91.43             92.38             92.38
# 98537                  90.48             90.48             90.48
# 98544                  85.71             85.71             85.71
# 98573                  95.24             95.24             95.24
# 98618                  92.38             91.43             90.48
# 98677                  92.38             93.33             94.29
# 98720                   0.00              0.00              0.00
# 98752                 100.00             99.05             98.10
# 98827                   4.76              4.76              4.76
# 98840                   0.00              0.00              0.00
# 9892                   90.48             90.48             90.48
# 99047                  85.71             85.71             86.67
# 99070                  86.67             67.62             48.57
# 99106                  90.48             90.48             90.48
# 99197                   4.76              4.76              4.76
# 99249                  87.62             89.52             91.43
# 99250                  95.24             95.24             95.24
# 99302                  95.24             96.19             97.14
# 99313                  90.48             90.48             90.48
# 99359                  95.24             95.24             95.24
# 99614                  76.19             76.19             76.19
# 99780                  80.95             80.95             80.95
# 9984                   95.24             95.24             95.24
#
#             2007:(2001-2005)  2006:(2000-2004)
# Instrument
# 1000045                82.86             82.86
# 1000157                90.48             90.48
# 1000177                92.38             91.43
# 1000180                95.24             95.24
# 1000184                85.71             87.62
# 1000209                80.95             80.95
# 1000227                90.48             90.48
# 1000228                90.48             90.48
# 1000229               100.00            100.00
# 1000230                95.24             95.24
# 1000232                57.14             57.14
# 1000234                57.14             57.14
# 1000275                57.14             57.14
# 1000278                95.24             95.24
# 1000297                85.71             85.71
# 1000298                76.19             76.19
# 1000300                80.95             80.95
# 1000368                10.48              7.62
# 1000623                95.24             95.24
# 1000683                90.48             90.48
# 1000694                89.52             88.57
# 1000695                95.24             95.24
# 1000697               100.00            100.00
# 1000736                95.24             95.24
# 1000753                95.24             95.24
# 1000779                85.71             85.71
# 1001082               100.00            100.00
# 1001085                74.29             72.38
# 1001111                43.81             25.71
# 1001113                80.95             80.95
# ...                      ...               ...
# 97517                  76.19             76.19
# 97745                  98.10             97.14
# 97854                  96.19             97.14
# 9801                   90.48             90.48
# 98222                  95.24             95.24
# 98246                  94.29             95.24
# 98338                  85.71             85.71
# 98362                  92.38             92.38
# 98537                  90.48             90.48
# 98544                  85.71             85.71
# 98573                  95.24             95.24
# 98618                  91.43             92.38
# 98677                  95.24             95.24
# 98720                   0.00              0.00
# 98752                  97.14             96.19
# 98827                   4.76              3.81
# 98840                   0.00              0.00
# 9892                   90.48             90.48
# 99047                  87.62             89.52
# 99070                  29.52             10.48
# 99106                  90.48             90.48
# 99197                   4.76              4.76
# 99249                  93.33             95.24
# 99250                  76.19             57.14
# 99302                  97.14             97.14
# 99313                  90.48             90.48
# 99359                  95.24             95.24
# 99614                  76.19             76.19
# 99780                  80.95             80.95
# 9984                   95.24             95.24
#
# [14761 rows x 14 columns]

# %% [markdown]
# ## Final Decision

# %%
# for the first step, remove the CIK with no filed/recorded 10-K forms
# read the csv file
cik_no10K = pd.read_csv('cik_without_10k.csv', header=None)

bad_cik = cik_no10K[0].to_list()

cik_no10K.head()
# Out:
#          0
# 0  1423221
# 1   704440
# 2  1616262
# 3   895564
# 4   315126

# %%
# just check a list of full rows companies, plus one totally empty one
check_list = [98840, 98222, 1001082, 1000697, 1000229, 1000180]

for cik in check_list:
    if cik in bad_cik:
        print(cik, 'is a bad CIK!')

print(len(bad_cik), 'bad CIK codes!')
healthy_fullness = dfout.reset_index()
healthy_fullness.head()
# Out:
# 933 bad CIK codes!
#   Instrument  2019:(2013-2017)  2018:(2012-2016)  2017:(2011-2015)  \
# 0    1000045             80.95             80.95             80.00
# 1    1000157             90.48             90.48             90.48
# 2    1000177             99.05             99.05             99.05
# 3    1000180            100.00            100.00            100.00
# 4    1000184             90.48             90.48             90.48
#
#    2016:(2010-2014)  2015:(2009-2013)  2014:(2008-2012)  2013:(2007-2011)  \
# 0             79.05             79.05             79.05             79.05
# 1             90.48             90.48             90.48             90.48
# 2             98.10             97.14             96.19             95.24
# 3            100.00            100.00            100.00            100.00
# 4             89.52             88.57             87.62             86.67
#
#    2012:(2006-2010)  2011:(2005-2009)  2010:(2004-2008)  2009:(2003-2007)  \
# 0             80.00             80.95             80.95             81.90
# 1             90.48             90.48             90.48             90.48
# 2             95.24             95.24             95.24             94.29
# 3            100.00             99.05             98.10             97.14
# 4             85.71             85.71             85.71             85.71
#
#    2008:(2002-2006)  2007:(2001-2005)  2006:(2000-2004)
# 0             82.86             82.86             82.86
# 1             90.48             90.48             90.48
# 2             93.33             92.38             91.43
# 3             96.19             95.24             95.24
# 4             85.71             85.71             87.62

# %%
# change cik codes format in bad_cik list to string
# so to be comparable with the Instrument column of
# our dataframe
print(type(bad_cik[1]))
print(type(healthy_fullness.Instrument[1]))
bad_cik = [str(cik) for cik in bad_cik]
type(bad_cik[1])
# Out:
# <class 'int'>
# <class 'str'>
# str

# %%
# drop companies with no filed 10-K form
healthy = healthy_fullness[~healthy_fullness.Instrument.isin(bad_cik)]
# check to make sure everything is okay and under control
print(len(healthy_fullness), '-', len(set(bad_cik)), '=', len(healthy))

healthy.head()
# Out:
# 14761 - 292 = 14469
#   Instrument  2019:(2013-2017)  2018:(2012-2016)  2017:(2011-2015)  \
# 0    1000045             80.95             80.95             80.00
# 1    1000157             90.48             90.48             90.48
# 2    1000177             99.05             99.05             99.05
# 3    1000180            100.00            100.00            100.00
# 4    1000184             90.48             90.48             90.48
#
#    2016:(2010-2014)  2015:(2009-2013)  2014:(2008-2012)  2013:(2007-2011)  \
# 0             79.05             79.05             79.05             79.05
# 1             90.48             90.48             90.48             90.48
# 2             98.10             97.14             96.19             95.24
# 3            100.00            100.00            100.00            100.00
# 4             89.52             88.57             87.62             86.67
#
#    2012:(2006-2010)  2011:(2005-2009)  2010:(2004-2008)  2009:(2003-2007)  \
# 0             80.00             80.95             80.95             81.90
# 1             90.48             90.48             90.48             90.48
# 2             95.24             95.24             95.24             94.29
# 3            100.00             99.05             98.10             97.14
# 4             85.71             85.71             85.71             85.71
#
#    2008:(2002-2006)  2007:(2001-2005)  2006:(2000-2004)
# 0             82.86             82.86             82.86
# 1             90.48             90.48             90.48
# 2             93.33             92.38             91.43
# 3             96.19             95.24             95.24
# 4             85.71             85.71             87.62

# %%
# create a new dictionary to save the fullest
# healthy companies for each period
cik_codes = {2000:[], 2001:[], 2002:[], 2003:[], 2004:[],
             2005:[], 2006:[], 2007:[], 2008:[], 2009:[],
             2010:[], 2011:[], 2012:[], 2013:[], 2014:[],
             2015:[], 2016:[], 2017:[]}

def CIK_picking(df, year, n):
    '''
    this function takes the healthy fullness dataframe,
    a year, and the number of bankrupt companies in the year (n),
    and produces a list including 5n healthy companies with
    the fullest rows in the period 7 to 2 years before that year,
    plus CIK of bankrupt companies in that year.
    The function, then, adds these CIK codes to the cik_codes'
    keys for each year in the period of 7-2 years before that year.
    And finally write the dictionary in a pickle file.
    '''
    
    # descending-sort the companies for that year
    col = str(year) + ':(' + str(year-6) + '-' + str(year-2) + ')'
    df.sort_values(by=[col], ascending=False, inplace=True)
    # make a list of their CIK cides
    CIK_list = df.Instrument.to_list()
    # cut the first n * 5 ones
    max_list = CIK_list[:5*n]
    # add bankrupt CIK in the 'year' to the list
    final_list = max_list + bankrupt[bankrupt.Date == year].CIK.to_list()
    
    for yr in range(year-6, year-1):
        cik_codes[yr] += final_list


# run the healthy_picking function for 14 years (2006-19)
for year in range(2006, 2020):
    # take the number of companies went bankrupt in that year
    n = dates.Company[year]
    # add the CIK lists to the cik_codes dictionary
    CIK_picking(healthy, year, n)
# Out:
# /Users/user/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Clear each cik_codes dictionary's key's list to make sure
# there ain't repetitive elements (CIKs) in them

# create a list, to store all CIKs
all_CIKs = []

for year in range(2000, 2018):
    cik_codes[year] = list(set(cik_codes[year]))
    all_CIKs += cik_codes[year]
    
# write the dictionary
with open('CIK_year.txt', 'wb') as f:
    pickle.dump(cik_codes, f)
    

# remove repetitive CIKs
all_CIKs = list(set(all_CIKs))
# the number of CIKs - the total number of bankrupt CIKs
# to check the number of healthy CIKs in our data
print('Final number of healthy companies in our dataset:', len(all_CIKs) - dates.Company.sum())
print('And the number of bankrupt companies in our dataset:', dates.Company.sum())
# Out:
# Final number of healthy companies in our dataset: 1152
# And the number of bankrupt companies in our dataset: 1055
