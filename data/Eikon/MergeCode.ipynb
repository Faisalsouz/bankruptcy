# %%
import pandas as pd
import functools

# %% [markdown]
# # Bankrupt Companies

# %%
functools.reduce(lambda x, y: pd.merge(x, y, on = 'index'), dfList)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-803ce81710b4> in <module>()
#       1
# ----> 2 functools.reduce(lambda x, y: pd.merge(x, y, on = 'index'), dfList)
#
# <ipython-input-31-803ce81710b4> in <lambda>(x, y)
#       1
# ----> 2 functools.reduce(lambda x, y: pd.merge(x, y, on = 'index'), dfList)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ...

# %%
# read the bankrupt csv files to a list
bankrupt_list = [pd.read_csv('data_bankrupt_CIK/' + 'bankrupt_data{}.csv'.format(i+1), dtype=object, index_col=0) for i in range(4)]


'''
# merge the dataframes
bankrupt = bankrupt.merge(healthy_tic2isn, on=['Ticker'], how='left')
functools.reduce(lambda x, y: pd.merge(x, y, on = 'Date'), dfList)

# Drop duplicate rowa resulted from the merge method
healthy = healthy.drop_duplicates(subset=None, keep='first', inplace=False)

# Drop duplicate rowa resulted from the merge method
healthy = healthy.drop_duplicates(subset=None, keep='first', inplace=False)
'''

bankrupt_list[0].head()
# Out:
#   Instrument Market Capitalisation Instrument Is Active Flag  \
# 0    1368218                   NaN                       0.0
# 1    1368218                   NaN                       NaN
# 2    1368218                   NaN                       NaN
# 3    1368218                   NaN                       NaN
# 4    1368218                   NaN                       NaN
#
#       Company Common Name  \
# 0  Tootie Pie Company Inc
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Total Inventory, 5 Year Compounded Annual Growth Rate (Pvt)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Total Current Assets Net Debt Incl. Pref.Stock & Min.Interest  \
# ...

# %%
bankrupt_list[0].describe()
# Out:
#        Instrument Business Earnings Before Interest and Taxes (EBIT)  \
# count       74388                                               1820
# unique       1103                                                302
# top       1045309                                       -388441000.0
# freq          306                                                 92
#
#        Total Debt Net Income/Starting Line, Cumulative Delisted Quote Flag  \
# count       61626                                62071                 895
# unique       7374                                 8932                   2
# top           0.0                          -57748000.0                 1.0
# freq         6430                                   92                 629
#
#        Total Current Liabilities Operating Income  \
# count                      54953            59887
# unique                      7967             8687
# top                   57498000.0              0.0
# ...

# %%
df = bankrupt_list[0]
df
# Out:
#       Instrument Market Capitalisation Instrument Is Active Flag  \
# 0        1368218                   NaN                       0.0
# 1        1368218                   NaN                       NaN
# 2        1368218                   NaN                       NaN
# 3        1368218                   NaN                       NaN
# 4        1368218                   NaN                       NaN
# 5        1368218                   NaN                       NaN
# 6        1368218                   NaN                       NaN
# 7        1368218                   NaN                       NaN
# 8        1368218                   NaN                       NaN
# 9        1368218                   NaN                       NaN
# 10       1368218                   NaN                       NaN
# 11       1368218                   NaN                       NaN
# 12       1368218                   NaN                       NaN
# ...

# %%
bankrupt_list[1].head()
# Out:
#   Instrument Tangible Book Value - Utility Market Capitalisation Stock Price  \
# 0     943605                    22688000.0                   NaN         NaN
# 1     943605                    53485000.0                   NaN         NaN
# 2     943605                    53485000.0                   NaN         NaN
# 3     943605                    53485000.0                   NaN         NaN
# 4     943605                    53485000.0                   NaN         NaN
#
#   Retained Earnings (Accumulated Deficit)  \
# 0                               5767000.0
# 1                              15878000.0
# 2                              15878000.0
# 3                              15878000.0
# 4                              15878000.0
#
#   Working Capital, Period over Period Average (Pvt)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# ...

# %%
bankrupt_list[1].describe()
# Out:
#        Instrument Tangible Book Value - Utility  Market Capitalisation  \
# count       73406                         61749                    0.0
# unique       1103                          9036                    0.0
# top        815508                           0.0                    NaN
# freq           78                           115                    NaN
#
#         Stock Price Retained Earnings (Accumulated Deficit)  \
# count           0.0                                   60312
# unique          0.0                                    8811
# top             NaN                                     0.0
# freq            NaN                                     189
#
#         Working Capital, Period over Period Average (Pvt)  \
# count                                                 0.0
# unique                                                0.0
# top                                                   NaN
# freq                                                  NaN
#
# ...

# %%
bankrupt_list[2].head()
# Out:
#   Instrument Total Assets, Reported Tangible Book Value - Reported  \
# 0     943605             65878000.0                     22688000.0
# 1     943605            156757000.0                     53485000.0
# 2     943605            156757000.0                     53485000.0
# 3     943605            156757000.0                     53485000.0
# 4     943605            156757000.0                     53485000.0
#
#   Instrument Is Active Flag Accounts Payable (CF)  \
# 0                       0.0              601000.0
# 1                       NaN              986000.0
# 2                       NaN              986000.0
# 3                       NaN              986000.0
# 4                       NaN              986000.0
#
#   Total Inventory, 5 Year Compounded Annual Growth Rate (Pvt)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
bankrupt_list[2].describe()
# Out:
#        Instrument Total Assets, Reported Tangible Book Value - Reported  \
# count       73560                  61966                          61749
# unique       1103                   9038                           9036
# top        815508                    0.0                            0.0
# freq           78                    320                            115
#
#        Instrument Is Active Flag Accounts Payable (CF)  \
# count                        895                 35515
# unique                         2                  4307
# top                          0.0                   0.0
# freq                         664                   494
#
#        Total Inventory, 5 Year Compounded Annual Growth Rate (Pvt)  \
# count                                                 542
# unique                                                 88
# top                                     -7.74516340680211
# freq                                                   57
#
# ...

# %%
bankrupt_list[3].head()
# Out:
#   Instrument Geographic Earnings Before Interest and Taxes (EBIT)  \
# 0     943605                                                NaN
# 1     943605                                                NaN
# 2     943605                                                NaN
# 3     943605                                                NaN
# 4     943605                                                NaN
#
#   GICS Industry Name Total Liabilities Depreciation And Amortization  \
# 0                NaN        13568000.0                           NaN
# 1                NaN        49343000.0                     2718000.0
# 2                NaN        49343000.0                     2718000.0
# 3                NaN        49343000.0                     2718000.0
# 4                NaN        49343000.0                     2718000.0
#
#   Total Current Assets                          NAICS Industry Group Name  \
# 0           32140000.0  Advertising, Public Relations, and Related Ser...
# ...

# %%
bankrupt_list[3].describe()
# Out:
#        Instrument Geographic Earnings Before Interest and Taxes (EBIT)  \
# count       73564                                                214
# unique       1103                                                 54
# top         26780                                                0.0
# freq          148                                                 20
#
#                  GICS Industry Name Total Liabilities  \
# count                           229             61780
# unique                           56              8954
# top     Oil, Gas & Consumable Fuels       335058000.0
# freq                             42                92
#
#        Depreciation And Amortization Total Current Assets  \
# count                          32525                54886
# unique                          4496                 7942
# top                              0.0                  0.0
# freq                             893                  391
#
# ...
