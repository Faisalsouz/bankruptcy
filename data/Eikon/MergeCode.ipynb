# %%
import pandas as pd
import functools

# %% [markdown]
# ## Read CSV Files

# %%
# read csv files and add bankrupt and year columns to the dataframes

# -------------------------------------------------------------------
# Bankrupt Companies
# -------------------------------------------------------------------
# make a list to add yearly dataframes to
bankrupt_list = []

# aggregate bankrupt companies by year
for year in range(2000, 2020):
    bankrupt_df = pd.concat([pd.read_csv('data_bankrupt/' + 'bankrupt_data{}_{}.csv'.format(i+1, year),
                                          dtype=object) for i in range(3)])
    
    # add the year value to each dataframe
    bankrupt_df['Year'] = year
    
    # add the year dataframe to the list
    bankrupt_list.append(bankrupt_df)

# concatenate all yearly dataframes
bankrupt = pd.concat(bankrupt_list)

# add the bankruptcy value to the dataframe
bankrupt['Bankrupt'] = 1


bankrupt.head()
# Out:
#   Instrument  Total Debt Accounts Payable (CF)  \
# 0     910655   1866000.0             -235000.0
# 1    1116521  10000000.0           -47000000.0
# 2     895651    377000.0                   NaN
# 3    1398702         NaN                   NaN
# 4    1434621         NaN                   NaN
#
#                       NAICS Industry Group Name Inventories (CF)  \
# 0  Motor Vehicle Body and Trailer Manufacturing       -9289000.0
# 1        Communications Equipment Manufacturing       81000000.0
# 2         Offices of Other Health Practitioners         289000.0
# 3                         Tobacco Manufacturing              NaN
# 4           Nondepository Credit Intermediation              NaN
#
#   Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 0                 1.0                              49741000.0
# 1                 1.0                                     NaN
# 2                 1.0                             -18251000.0
# ...

# %%
# read csv files and add bankrupt and year columns to the dataframes

# -------------------------------------------------------------------
# Healthy Companies
# -------------------------------------------------------------------
# make a list to add yearly dataframes to
healthy_list = []

# aggregate healthy companies by year
for year in range(2000, 2020):
    healthy_df = pd.concat([pd.read_csv('data_healthy/' + 'healthy_data{}_{}.csv'.format(i+1, year),
                                          dtype=object) for i in range(30)])
    
    # add the year value to each dataframe
    healthy_df['Year'] = year
    
    # add the year dataframe to the list
    healthy_list.append(healthy_df)

# concatenate all yearly dataframes
healthy = pd.concat(healthy_list)

# add the bankruptcy value to the dataframe
healthy['Bankrupt'] = 0


healthy.head()
# Out:
#   Instrument    Total Debt Accounts Payable (CF)  \
# 0       1750   181359000.0            24659000.0
# 1      61478    49900000.0            45000000.0
# 2     319126     6402000.0             -300000.0
# 3     730469   483008000.0                   NaN
# 4       6201  4402000000.0                   NaN
#
#                            NAICS Industry Group Name Inventories (CF)  \
# 0          Aerospace Product and Parts Manufacturing      -46212000.0
# 1             Communications Equipment Manufacturing      -66700000.0
# 2  Navigational, Measuring, Electromedical, and C...         665000.0
# 3                   Other Investment Pools and Funds        1255000.0
# 4                       Scheduled Air Transportation      -36000000.0
#
#   Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 0                 0.0                             184529000.0
# 1                 1.0                             899200000.0
# ...

# %% [markdown]
# ## The Big Boss of the Concatenations

# %%
data = pd.concat([bankrupt, healthy])

data.head()
# Out:
#   Instrument  Total Debt Accounts Payable (CF)  \
# 0     910655   1866000.0             -235000.0
# 1    1116521  10000000.0           -47000000.0
# 2     895651    377000.0                   NaN
# 3    1398702         NaN                   NaN
# 4    1434621         NaN                   NaN
#
#                       NAICS Industry Group Name Inventories (CF)  \
# 0  Motor Vehicle Body and Trailer Manufacturing       -9289000.0
# 1        Communications Equipment Manufacturing       81000000.0
# 2         Offices of Other Health Practitioners         289000.0
# 3                         Tobacco Manufacturing              NaN
# 4           Nondepository Credit Intermediation              NaN
#
#   Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 0                 1.0                              49741000.0
# 1                 1.0                                     NaN
# 2                 1.0                             -18251000.0
# ...

# %%
data.describe(include = 'all')
# Out:
#        Instrument Total Debt Accounts Payable (CF)  \
# count      345740     215884                118284
# unique      15221      89446                 40551
# top       1047919        0.0                   0.0
# freq          120      44786                  1934
# mean          NaN        NaN                   NaN
# std           NaN        NaN                   NaN
# min           NaN        NaN                   NaN
# 25%           NaN        NaN                   NaN
# 50%           NaN        NaN                   NaN
# 75%           NaN        NaN                   NaN
# max           NaN        NaN                   NaN
#
#                NAICS Industry Group Name Inventories (CF) Delisted Quote Flag  \
# count                             305160           111409              282160
# unique                               285            38425                   2
# top     Other Investment Pools and Funds              0.0                 0.0
# ...

# %%
# write the data csv file
data.to_csv('data.csv', index=False)
