# %%
import pandas as pd
import numpy as np
import os

# %%
# read the data file
data = pd.read_csv('data.csv', dtype=object)

data.head()
# Out:
#   Instrument  Total Debt Accounts Payable (CF)  \
# 0     910655   1866000.0             -235000.0
# 1    1116521  10000000.0           -47000000.0
# 2     895651    377000.0                   NaN
# 3    1398702         NaN                   NaN
# 4    1434621         NaN                   NaN
#
#                       NAICS Industry Group Name Inventories (CF)  \
# 0  Motor Vehicle Body and Trailer Manufacturing       -9289000.0
# 1        Communications Equipment Manufacturing       81000000.0
# 2         Offices of Other Health Practitioners         289000.0
# 3                         Tobacco Manufacturing              NaN
# 4           Nondepository Credit Intermediation              NaN
#
#   Delisted Quote Flag Retained Earnings (Accumulated Deficit)  \
# 0                 1.0                              49741000.0
# 1                 1.0                                     NaN
# 2                 1.0                             -18251000.0
# ...

# %%
data.describe(include = 'all')
# Out:
#        Instrument Total Debt Accounts Payable (CF)  \
# count      345740     215884                118284
# unique      15221      89446                 40551
# top       1310094        0.0                   0.0
# freq          120      44786                  1934
#
#                NAICS Industry Group Name Inventories (CF) Delisted Quote Flag  \
# count                             305160           111409              282160
# unique                               285            38425                   2
# top     Other Investment Pools and Funds              0.0                 0.0
# freq                               24040             3143              171960
#
#        Retained Earnings (Accumulated Deficit)  \
# count                                   209727
# unique                                  132639
# top                                        0.0
# freq                                       899
#
#        Net Debt Incl. Pref.Stock & Min.Interest Total Current Assets  \
# ...

# %%
data.columns
# Out:
# Index(['Instrument', 'Total Debt', 'Accounts Payable (CF)',
#        'NAICS Industry Group Name', 'Inventories (CF)', 'Delisted Quote Flag',
#        'Retained Earnings (Accumulated Deficit)',
#        'Net Debt Incl. Pref.Stock & Min.Interest', 'Total Current Assets',
#        'Total Liabilities', 'Company Common Name', 'CIK Number',
#        'Total Equity', 'Tangible Book Value - Banks',
#        'Tangible Book Value - Insurance',
#        'Net Income/Starting Line, Cumulative',
#        'Tangible Book Value - Reported', 'Cash and Short Term Investments',
#        'Market Value for Company', 'Tangible Book Value Per Share',
#        'Net Sales', 'Operating Income', 'Instrument Is Active Flag',
#        'Tangible Book Value - Utility', 'Total Assets, Reported',
#        'Depreciation And Amortization', 'Total Current Liabilities', 'Year',
#        'Bankrupt'],
#       dtype='object')

# %%
datan = data.drop(columns=['NAICS Industry Group Name', 'Delisted Quote Flag', 'Company Common Name',
                   'CIK Number', 'Instrument Is Active Flag'])

# %%
test = datan.dropna()
test['Bankrupt'] = test['Bankrupt'].apply(lambda x: int(x))

test = test.groupby('Instrument').count()
# Out:
# /Users/user/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test
# Out:
#             Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# Instrument
# 1000177              7                      7                 7
# 1000180             14                     14                14
# 1000229             20                     20                20
# 1000230              1                      1                 1
# 1000697             20                     20                20
# 1001082             20                     20                20
# 1001288              1                      1                 1
# 1001426              2                      2                 2
# 1001463              4                      4                 4
# 1001474             13                     13                13
# 1001614             20                     20                20
# 1001903             15                     15                15
# 1002047              5                      5                 5
# ...

# %%
test2 = test.loc[test['Bankrupt'] == 20].reset_index()
test2
# Out:
#     Instrument  Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# 0      1000229          20                     20                20
# 1      1000697          20                     20                20
# 2      1001082          20                     20                20
# 3      1001614          20                     20                20
# 4      1002242          20                     20                20
# 5      1003214          20                     20                20
# 6      1005229          20                     20                20
# 7      1008817          20                     20                20
# 8       100885          20                     20                20
# 9      1009244          20                     20                20
# 10     1010552          20                     20                20
# 11     1013488          20                     20                20
# 12     1014739          20                     20                20
# ...

# %%
no_nans_CIK_list = test2['Instrument'].to_list()
print(len(no_nans_CIK_list))
type(no_nans_CIK_list[0])
# Out:
# 200
# str

# %%
print(datan.shape)
type(datan.Instrument[1])
# Out:
# (345740, 24)
# str

# %%
data_test = datan.loc[data['Instrument'].isin(no_nans_CIK_list)]
data_test = data_test.dropna()
data_test.sort_values(by=['Instrument', 'Year'], inplace=True)
data_test = data_test.reset_index().drop(columns=['index'])

data_test_bankrupt = data_test[data_test.Bankrupt == '1']
data_test_healthy = data_test[data_test.Bankrupt == '0']

# %%
if not os.path.exists('small_test_sets'):
    os.makedirs('small_test_sets')

# %%
data_test_bankrupt.to_csv('small_test_sets/data_test_bankrupt.csv', index=False)

data_test_bankrupt
# Out:
#      Instrument    Total Debt Accounts Payable (CF) Inventories (CF)  \
# 860     1071645   151023000.0             6743000.0      -24761000.0
# 861     1071645   492175000.0             7397000.0         578000.0
# 862     1071645   492175000.0             7397000.0         578000.0
# 863     1071645   492175000.0             7397000.0         578000.0
# 864     1071645   492175000.0             7397000.0         578000.0
# 865     1071645   492175000.0             7397000.0         578000.0
# 866     1071645   492175000.0             7397000.0         578000.0
# 867     1071645   492175000.0             7397000.0         578000.0
# 868     1071645   492175000.0             7397000.0         578000.0
# 869     1071645   492175000.0             7397000.0         578000.0
# 870     1071645   492175000.0             7397000.0         578000.0
# 871     1071645   492175000.0             7397000.0         578000.0
# 872     1071645   492175000.0             7397000.0         578000.0
# ...

# %%
data_test_healthy.to_csv('small_test_sets/data_test_healthy.csv', index=False)

data_test_healthy
# Out:
#      Instrument   Total Debt Accounts Payable (CF) Inventories (CF)  \
# 0       1000229   89686000.0            -9952000.0       -2595000.0
# 1       1000229   88803000.0             -939000.0      -11982000.0
# 2       1000229   84020000.0             5025000.0       -8542000.0
# 3       1000229   95627000.0            -6798000.0       -2190000.0
# 4       1000229   89180000.0             3971000.0        5037000.0
# 5       1000229  128101000.0             4314000.0        3428000.0
# 6       1000229  113200000.0             3142000.0        -904000.0
# 7       1000229   88648000.0             3926000.0       -2988000.0
# 8       1000229  302764000.0             6254000.0       -4138000.0
# 9       1000229  303027000.0             2173000.0        1047000.0
# 10      1000229  194568000.0             1454000.0       -5576000.0
# 11      1000229  209112000.0            -8579000.0        1847000.0
# 12      1000229  147543000.0            11701000.0       -2438000.0
# ...

# %% [markdown]
# ## check what is wrong with the 110-3890

# %%
data_test_healthy_check = data_test_healthy.copy()
data_test_healthy_check['Bankrupt'] = data_test_healthy_check['Bankrupt'].apply(lambda x: int(x))

data_test_healthy_check = data_test_healthy_check.groupby('Instrument').count()

data_test_healthy_check
# Out:
#             Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# Instrument
# 1000229             20                     20                20
# 1000697             20                     20                20
# 1001082             20                     20                20
# 1001614             20                     20                20
# 1002242             20                     20                20
# 1003214             20                     20                20
# 1005229             20                     20                20
# 1008817             20                     20                20
# 100885              20                     20                20
# 1009244             20                     20                20
# 1010552             20                     20                20
# 1013488             20                     20                20
# 1014739             20                     20                20
# ...

# %%
ins_healthy = data_test_healthy_check[data_test_healthy_check['Bankrupt'] != 20]
ins_healthy
# Out:
#             Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# Instrument
# 1396279             10                     10                10
# 318259              10                     10                10
# 842162              10                     10                10
#
#             Retained Earnings (Accumulated Deficit)  \
# Instrument
# 1396279                                          10
# 318259                                           10
# 842162                                           10
#
#             Net Debt Incl. Pref.Stock & Min.Interest  Total Current Assets  \
# Instrument
# 1396279                                           10                    10
# 318259                                            10                    10
# 842162                                            10                    10
#
#             Total Liabilities  Total Equity  Tangible Book Value - Banks  \
# Instrument
# ...

# %%
healthy_remove_list = ins_healthy.reset_index().Instrument.to_list()
print(healthy_remove_list)
# Out:
# ['1396279', '318259', '842162']

# %%
data_test_bankrupt_check = data_test_bankrupt.copy()
data_test_bankrupt_check['Bankrupt'] = data_test_bankrupt_check['Bankrupt'].apply(lambda x: int(x))

data_test_bankrupt_check = data_test_bankrupt_check.groupby('Instrument').count()

data_test_bankrupt_check
# Out:
#             Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# Instrument
# 1071645             20                     20                20
# 1083753             20                     20                20
# 1396279             10                     10                10
# 318259              10                     10                10
# 835540              20                     20                20
# 842162              10                     10                10
# 925178              20                     20                20
#
#             Retained Earnings (Accumulated Deficit)  \
# Instrument
# 1071645                                          20
# 1083753                                          20
# 1396279                                          10
# 318259                                           10
# 835540                                           20
# 842162                                           10
# 925178                                           20
#
# ...

# %%
print(len(no_nans_CIK_list))

nono_list = list(set(no_nans_CIK_list) - set(healthy_remove_list))

len(nono_list)
# Out:
# 200
# 197

# %%
print(datan.shape)
# Out:
# (345740, 24)

# %%
data_tesst = datan.loc[data['Instrument'].isin(nono_list)]
data_tesst = data_tesst.dropna()
data_tesst.sort_values(by=['Instrument', 'Year'], inplace=True)
data_tesst = data_tesst.reset_index().drop(columns=['index'])

data_test_bankrupt = data_tesst[data_tesst.Bankrupt == '1']
data_test_healthy = data_tesst[data_tesst.Bankrupt == '0']

# %%
data_test_bankrupt.to_csv('small_test_sets/data_test_bankrupt.csv', index=False)

data_test_bankrupt
# Out:
#      Instrument    Total Debt Accounts Payable (CF) Inventories (CF)  \
# 860     1071645   151023000.0             6743000.0      -24761000.0
# 861     1071645   492175000.0             7397000.0         578000.0
# 862     1071645   492175000.0             7397000.0         578000.0
# 863     1071645   492175000.0             7397000.0         578000.0
# 864     1071645   492175000.0             7397000.0         578000.0
# 865     1071645   492175000.0             7397000.0         578000.0
# 866     1071645   492175000.0             7397000.0         578000.0
# 867     1071645   492175000.0             7397000.0         578000.0
# 868     1071645   492175000.0             7397000.0         578000.0
# 869     1071645   492175000.0             7397000.0         578000.0
# 870     1071645   492175000.0             7397000.0         578000.0
# 871     1071645   492175000.0             7397000.0         578000.0
# 872     1071645   492175000.0             7397000.0         578000.0
# ...

# %%
data_test_healthy.to_csv('small_test_sets/data_test_healthy.csv', index=False)

data_test_healthy
# Out:
#      Instrument   Total Debt Accounts Payable (CF) Inventories (CF)  \
# 0       1000229   89686000.0            -9952000.0       -2595000.0
# 1       1000229   88803000.0             -939000.0      -11982000.0
# 2       1000229   84020000.0             5025000.0       -8542000.0
# 3       1000229   95627000.0            -6798000.0       -2190000.0
# 4       1000229   89180000.0             3971000.0        5037000.0
# 5       1000229  128101000.0             4314000.0        3428000.0
# 6       1000229  113200000.0             3142000.0        -904000.0
# 7       1000229   88648000.0             3926000.0       -2988000.0
# 8       1000229  302764000.0             6254000.0       -4138000.0
# 9       1000229  303027000.0             2173000.0        1047000.0
# 10      1000229  194568000.0             1454000.0       -5576000.0
# 11      1000229  209112000.0            -8579000.0        1847000.0
# 12      1000229  147543000.0            11701000.0       -2438000.0
# ...
