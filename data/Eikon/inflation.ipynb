# %%
import pandas as pd

# %%
# inflation rate in North America
inflation = {
    2000: 3.048,
    2001: 2.676,
    2002: 1.922,
    2003: 2.514,
    2004: 2.267,
    2005: 2.803,
    2006: 2.614,
    2007: 2.496,
    2008: 3.105,
    2009: -.028,
    2010: 1.708,
    2011: 3.034,
    2012: 1.793,
    2013: 1.202,
    2014: 1.764,
    2015: 0.622,
    2016: 1.345,
    2017: 1.863,
    2018: 2.355,
}

# %%
data = pd.read_csv('/Users/user/Documents/Bankruptcy/bankruptcy/data/processed/data.csv', index_col=None)
data.head()
# Out:
#     CIK  Year  Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# 0  1750  2003    0.000005              -0.025690         -0.041836
# 1  1750  2004    0.000005              -0.025680         -0.041751
# 2  1750  2005    0.000005              -0.025676         -0.041755
# 3  1750  2006    0.000004              -0.025671         -0.041802
# 4  1750  2007    0.000006              -0.025670         -0.041881
#
#    Retained Earnings (Accumulated Deficit)  \
# 0                                -0.997354
# 1                                -0.997355
# 2                                -0.997355
# 3                                -0.997354
# 4                                -0.997353
#
#    Net Debt Incl. Pref.Stock & Min.Interest  Total Current Assets  \
# 0                                 -0.998423              0.000015
# 1                                 -0.998422              0.000014
# 2                                 -0.998423              0.000015
# ...
