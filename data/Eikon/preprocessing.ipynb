# %%
import numpy as np
import pandas as pd

import pickle

# %%
# read the dictionary of CIK codes
with open('CIK_year.txt', 'rb') as fp:
    CIK = pickle.load(fp)
    

# convert all CIK codes in the dictionary to strings
for key, value in CIK.items():
    CIK[key] = [str(cik) for cik in value]
            

# read the csv of data
data = pd.read_csv('data.csv', dtype={'Instrument': 'str'})

# %%
unique_CIKs = len(list(set(data.Instrument.to_list())))
print(unique_CIKs)
len(data.Instrument.unique())
# Out:
# 15221
# 15221

# %%
# creat a list to add all CIK codes to
CIK_list = []

# iterating over the dictionary items and add CIK lists to our list
for key, value in CIK.items():
    CIK_list += value

# remove duplicated elements
CIK_list = list(set(CIK_list))

print('There are', len(CIK_list), 'CIK codes in our list.')

CIK_list
# Out:
# There are 2220 CIK codes in our list.
# ['0001279676',
#  '0001047153',
#  '1487101',
#  '7332',
#  '0001341843',
#  '0000704384',
#  '14280',
#  '1374328',
#  '42136',
#  '899751',
#  '318259',
#  '837173',
#  '0000840889',
#  '0001086385',
#  '0001015979',
#  '1001385',
#  '0000002034',
#  '0001020475',
#  '0001097805',
#  '0001176193',
#  '850693',
#  '0001343202',
#  '0000093542',
#  '0001389053',
#  '919642',
#  '0000874841',
#  '0000776008',
#  '799097',
#  '1295810',
#  '1024126',
#  '1582244',
#  '1081751',
#  '863650',
#  '0001124608',
#  '932787',
#  '836429',
#  '932696',
#  '0001271833',
#  '0000797331',
#  '1002517',
#  '1100270',
#  '0000739708',
#  '874759',
#  '0001475899',
#  '0001014763',
#  '0000884719',
#  '0001121745',
#  '876427',
#  '1334036',
#  '1325955',
#  '884624',
#  '1058090',
#  '0001346526',
#  '0001178818',
#  '1232524',
#  '926295',
#  '1063254',
#  '1040130',
#  '1037461',
#  '812301',
#  '75288',
#  '0000827809',
#  '940944',
#  '0000935063',
#  '0001584952',
#  '1049502',
#  '914122',
#  '1009672',
#  '1098972',
#  '0000810208',
#  '355019',
#  '0001159154',
#  '897723',
#  '0001072765',
#  '1442505',
#  '0000837173',
#  '0001399311',
#  '0001310067',
#  '0001143566',
#  '0000880460',
#  '864749',
#  '0000718007',
#  '0001023994',
#  '0001403433',
#  '768835',
#  '0000764794',
#  '1406243',
#  '0000946661',
#  '0001010610',
#  '0001176325',
#  '1326652',
#  '0001554875',
#  '110430',
#  '875762',
#  '0000016104',
#  '0000758256',
#  '1315257',
#  '1419428',
#  '778734',
#  '0001085475',
#  '0001534287',
#  '0001487561',
#  '1023514',
#  '852570',
#  '1078271',
#  '1257803',
#  '0001349436',
#  '737572',
#  '1096376',
#  '1082038',
#  '1190723',
#  '1045810',
#  '0001232229',
#  '1057232',
#  '1020017',
#  '0001056756',
#  '40987',
#  '1044896',
#  '0000797329',
#  '913590',
#  '4127',
#  '0001256536',
#  '892907',
#  '0001376812',
#  '928421',
#  '17485',
#  '1125259',
#  '0000030197',
#  '103730',
#  '1463972',
#  '0000728249',
#  '1489136',
#  '0001062613',
#  '1439288',
#  '0000898660',
#  '1037646',
#  '0001166380',
#  '1385544',
#  '0001294250',
#  '1113232',
#  '2488',
#  '1667966',
#  '1013488',
#  '95585',
#  '0000852766',
#  '1047857',
#  '1041577',
#  '1084031',
#  '0000081050',
#  '817720',
#  '0001341853',
#  '1070412',
#  '730263',
#  '2491',
#  '1038541',
#  '783412',
#  '0001299716',
#  '1116942',
#  '0000023778',
#  '1406574',
#  '1020391',
#  '1303849',
#  '310568',
#  '0001379905',
#  '1030485',
#  '932145',
#  '0000076791',
#  '1059677',
#  '71557',
#  '70318',
#  '1043604',
#  '0001028985',
#  '0000797448',
#  '49754',
#  '1060426',
#  '1325281',
#  '927454',
#  '0001405424',
#  '0001452384',
#  '889900',
#  '23197',
#  '0001363346',
#  '949158',
#  '0001138173',
#  '0000940510',
#  '0001096339',
#  '0001107601',
#  '1056794',
#  '817129',
#  '1003481',
#  '0000019731',
#  '0001014052',
#  '0000778164',
#  '1060390',
#  '919722',
#  '1418135',
#  '29002',
#  '1058027',
#  '1267097',
#  '0000744106',
#  '0001377053',
#  '0000878802',
#  '56873',
#  '916540',
#  '1056386',
#  '928054',
#  '1040161',
#  '95302',
#  '0001341293',
#  '70145',
#  '918964',
#  '0001145061',
#  '0001058767',
#  '0000357097',
#  '0001042582',
#  '105634',
#  '0001048566',
#  '0001323770',
#  '1381531',
#  '0000744962',
#  '63814',
#  '355777',
#  '0001368147',
#  '0000072911',
#  '1007587',
#  '0001355128',
#  '880059',
#  '809933',
#  '0001210936',
#  '0001270597',
#  '0001575599',
#  '0000054291',
#  '1092807',
#  '0001432987',
#  '0000806624',
#  '1425905',
#  '1016281',
#  '1043000',
#  '1074436',
#  '0001097081',
#  '0000923529',
#  '0000941020',
#  '864240',
#  '1022408',
#  '919012',
#  '943452',
#  '854701',
#  '0000947397',
#  '0000314606',
#  '929994',
#  '0001396279',
#  '949157',
#  '0000821483',
#  '1126113',
#  '0000855109',
#  '0001379763',
#  '0001108951',
#  '0000714756',
#  '0001393861',
#  '0001104161',
#  '758938',
#  '0001302502',
#  '945641',
#  '0000935493',
#  '1088213',
#  '0001368883',
#  '1014507',
#  '0000859735',
#  '100625',
#  '71691',
#  '0001073429',
#  '887497',
#  '34088',
#  '866830',
#  '10048',
#  '0001311230',
#  '0000724571',
#  '1288741',
#  '929299',
#  '0000352079',
#  '0001081074',
#  ...]

# %%
# drop non-quantitative columns
data_cl = data.drop(columns=['NAICS Industry Group Name', 'Delisted Quote Flag', 'Company Common Name',
                                    'CIK Number', 'Instrument Is Active Flag', 'Bankrupt'])
# check on the data shape
print(data_cl.shape)

data_cl.head()
# Out:
# (345740, 23)
#   Instrument  Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# 0     910655   1866000.0              -235000.0        -9289000.0
# 1    1116521  10000000.0            -47000000.0        81000000.0
# 2     895651    377000.0                    NaN          289000.0
# 3    1398702         NaN                    NaN               NaN
# 4    1434621         NaN                    NaN               NaN
#
#    Retained Earnings (Accumulated Deficit)  \
# 0                               49741000.0
# 1                                      NaN
# 2                              -18251000.0
# 3                                      NaN
# 4                                      NaN
#
#    Net Debt Incl. Pref.Stock & Min.Interest  Total Current Assets  \
# 0                                -8580000.0          8.268900e+07
# 1                              -184000000.0          3.043000e+09
# 2                                -1483000.0          9.479000e+06
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
#
#    Total Liabilities  Total Equity  Tangible Book Value - Banks  ...  \
# 0       2.325000e+07  9.448900e+07                 8.712400e+07  ...
# 1       2.422000e+09  1.817000e+09                 1.556000e+09  ...
# 2       1.318600e+07  1.895900e+07                 3.622000e+06  ...
# 3                NaN           NaN                          NaN  ...
# 4                NaN           NaN                          NaN  ...
#
#    Cash and Short Term Investments  Market Value for Company  \
# 0                       10446000.0               195540000.0
# 1                      194000000.0                       NaN
# 2                        1860000.0                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
#
#    Tangible Book Value Per Share     Net Sales  Operating Income  \
# 0                        8.43993  3.603260e+08        40075000.0
# 1                        5.59129  8.268000e+09       369000000.0
# 2                        0.40670  5.497100e+07        -1056000.0
# 3                            NaN           NaN               NaN
# 4                            NaN           NaN               NaN
#
#    Tangible Book Value - Utility  Total Assets, Reported  \
# 0                   8.712400e+07            1.177390e+08
# 1                   1.556000e+09            4.239000e+09
# 2                   3.622000e+06            3.214500e+07
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
#    Depreciation And Amortization  Total Current Liabilities  Year
# 0                       413000.0               1.920900e+07  2000
# 1                            NaN               1.597000e+09  2000
# 2                            NaN               6.303000e+06  2000
# 3                            NaN                        NaN  2000
# 4                            NaN                        NaN  2000
#
# [5 rows x 23 columns]

# %%
# drop the all companies but the ones in the CIK list
data_cl = data_cl[data_cl.Instrument.isin(CIK_list)]

print('Data df shape:', data_cl.shape, '\n')

print('If every thing is okay, then the number of unique CIK in semi-clean data,', len(data_cl.Instrument.unique()))

print()
print('Let\'s check:')
print(len(data_cl.Instrument.unique()))


data_cl.head()
# Out:
# Data df shape: (28800, 23)
#
# If every thing is okay, then the number of unique CIK in semi-clean data, 1234
#
# Let's check:
# 1234
#    Instrument   Total Debt  Accounts Payable (CF)  Inventories (CF)  \
# 15    1419428          NaN                    NaN               NaN
# 17    1402281          NaN                    NaN               NaN
# 18    1346685          NaN                    NaN               NaN
# 36    1080029    3814000.0               202000.0               NaN
# 45     940510  140400000.0            126500000.0      -140500000.0
#
#     Retained Earnings (Accumulated Deficit)  \
# 15                                      NaN
# 17                                      NaN
# 18                                      NaN
# 36                               -2606000.0
# 45                               36400000.0
#
#     Net Debt Incl. Pref.Stock & Min.Interest  Total Current Assets  \
# 15                                       NaN                   NaN
# 17                                       NaN                   NaN
# 18                                       NaN                   NaN
# 36                                 3814000.0          1.334000e+06
# 45                                97600000.0          1.133300e+09
#
#     Total Liabilities  Total Equity  Tangible Book Value - Banks  ...  \
# 15                NaN           NaN                          NaN  ...
# 17                NaN           NaN                          NaN  ...
# 18                NaN           NaN                          NaN  ...
# 36       4.930000e+06    -1663000.0                   -1663000.0  ...
# 45       1.051500e+09   715100000.0                  609100000.0  ...
#
#     Cash and Short Term Investments  Market Value for Company  \
# 15                              NaN                       NaN
# 17                              NaN              1.300000e+05
# 18                              NaN              1.670000e+06
# 36                              0.0              3.823900e+08
# 45                       42800000.0              1.217840e+09
#
#     Tangible Book Value Per Share     Net Sales  Operating Income  \
# 15                            NaN           NaN               NaN
# 17                            NaN           NaN               NaN
# 18                            NaN           NaN               NaN
# 36                       -0.26374  8.020000e+06        -2373000.0
# 45                        7.83962  2.595000e+09       167300000.0
#
#     Tangible Book Value - Utility  Total Assets, Reported  \
# 15                            NaN                     NaN
# 17                            NaN                     NaN
# 18                            NaN                     NaN
# 36                     -1663000.0            3.265000e+06
# 45                    609100000.0            1.766600e+09
#
#     Depreciation And Amortization  Total Current Liabilities  Year
# 15                            NaN                        NaN  2000
# 17                            NaN                        NaN  2000
# 18                            NaN                        NaN  2000
# 36                      1084000.0                  3885000.0  2000
# 45                      2900000.0                988800000.0  2000
#
# [5 rows x 23 columns]

# %%
data.describe()

# %%
data_cl.describe()

# %%
# just checking...
data_cl.sort_values(by=['Instrument', 'Year'])

# %%
# check the type of Instrument entries
print('Datatype of the Instrument column in our datafram:')
print(type(data_cl.Instrument[15]))
print('Datatype of the Year column in our datafram:')
print(type(data_cl.Year[15]))
print()

# check the type of CIK entries in the CIK dictionary
for key, value in CIK.items():
    print('Datatype of the CIK in our dictionary:')
    print(type(value[0]))
    print('Datatype of the Year in our dictionary:')
    print(type(key))
    break

# %%
# iterate over the dictionary, and for each year concatanate 
# the corresponding five years for each company in the list
# to the final dataframe: datum.

# create an empty df with the data columns
datum = pd.DataFrame(columns=data_cl.columns)

# iterate over the dictionary
for key, value in CIK.items():
    # for each company (cik) in the list of the year (key)
    for cik in value:
        # take rows of the data for that cik code and the same year as key
        df = data_cl[(data_cl.Instrument == cik) & (data_cl.Year == str(key))]
        datum = pd.concat([datum, df])

print(datum.shape)
datum.head()

# %%
# just checking...

print(datum.shape)

datum.sort_values(by=['Instrument', 'Year'])

# %%
datum.drop_duplicates(inplace=True)

# checking for fishy duplicated rows
check_dup = datum.dropna()
check_dup = check_dup.groupby(['Instrument', 'Year']).count()

# check for duplicates
for col in check_dup.columns:
    print(check_dup[col].value_counts())
    print()

print(datum.shape)

# %% [markdown]
# So, pretty shitty!

# %%
# write the datum as csv file
# and read it again, sorry!
# just that it's easier than to convert all factors to integer

datum.to_csv('datum.csv', index=False)
datum = pd.read_csv('datum.csv')

datum.head()

# %%
# first check if we actually have all CIK in the dictionary
# and for all the required years

# for each year (key)
for key, value in CIK.items():
    # for each company (cik) in that year's list
    for cik in value:
        df = data_cl[(data_cl.Instrument == cik) & (data_cl.Year == str(key))]
        df.groupy()
